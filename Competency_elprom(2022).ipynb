# %% [markdown]
# # Компетенции ELPROM (2022)

# %% [markdown]
# ### Личностные качества и KPI

# %% [markdown]
# #### Влияние и важность признаков

# %%
shap_values = explainer.shap_values(train)
shap.summary_plot(shap_values, train, feature_names)

# %% [markdown]
# #### Коррелограмма

# %%
import seaborn as sns

# %%
# Plot
plt.figure(figsize=(8,8), dpi= 70)
sns.heatmap(dataset1.corr(), xticklabels=dataset1.corr().columns, yticklabels=dataset1.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Личностные качества', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ### Менеджерские качества и KPI

# %% [markdown]
# #### Влияние и важность признаков

# %%
shap_values = explainer.shap_values(train)
shap.summary_plot(shap_values, train, feature_names)

# %% [markdown]
# #### Коррелограмма

# %%
# Plot
plt.figure(figsize=(15,15), dpi= 70)
sns.heatmap(dataset2.corr(), xticklabels=dataset2.corr().columns, yticklabels=dataset2.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Менеджерские качества', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ### Управленческие качества и KPI

# %% [markdown]
# #### Влияние и важность признаков

# %%
shap_values = explainer.shap_values(train)
shap.summary_plot(shap_values, train, feature_names)

# %% [markdown]
# #### Коррелограмма

# %%
# Plot
plt.figure(figsize=(15,15), dpi= 70)
sns.heatmap(dataset3.corr(), xticklabels=dataset3.corr().columns, yticklabels=dataset3.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Управленческие качества', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
